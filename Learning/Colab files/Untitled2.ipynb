# %%
import os
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore', category=UserWarning, module='pandas')

# %%
from google.colab import drive
drive.mount("/content/drive")
# !ls
# Out:
# Mounted at /content/drive
# drive  sample_data

# %%
path="drive/MyDrive/Dong-Data"
# !ls "drive/MyDrive/Dong-Data"
